# %% [markdown]
# # Explo et debug

# %%
from pathlib import Path

from tools.init_logging import load_logging_configuration
from data_handling.database_service import DatabaseService

# %%
logging_file = Path(Path.cwd(), "tools", "logging.yml")
load_logging_configuration(logging_file)

db_service = DatabaseService()

# %%
db_service.get_year_competitions(2016)

# %%
res = db_service.get_competition_participations(
    "Sélectif Régional de slalom Evrunes - Gazeau Evrunes - Finale - 2016-01-10"
)
res = list(res)
for p in res:
    print(p)

# %%
res = db_service.get_todays_competitor_ranking("Charles Dampeyrou", "C1H")
print(res)
